# %%
import pkg_resources
import types

# %%
from delight.io import *
from delight.interfaces.rail.processFilters import *

# %%
def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            # Split ensures you get root package, 
            # not just imported function
            name = val.__name__.split(".")[0]

        elif isinstance(val, type):
            name = val.__module__.split(".")[0]

        # Some packages are weird and have different
        # imported names vs. system/pip names. Unfortunately,
        # there is no systematic way to get pip names from
        # a package's imported name. You'll have to add
        # exceptions to this list manually!
        poorly_named_packages = {
            "PIL": "Pillow",
            "sklearn": "scikit-learn"
        }
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]

        yield name

# %%
imports = list(set(get_imports()))

# The only way I found to get the version of the root package
# from only the name of the package is to cross-check the names 
# of installed packages vs. imported packages
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name!="pip":
        requirements.append((m.project_name, m.version))

for r in requirements:
    print("{}=={}".format(*r))
# Out:
# scipy==1.7.1
# numpy==1.21.2
# configparser==5.0.2
# coloredlogs==15.0.1
# delight==1.0.1

# %%
print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# numpy==1.20.1
# coloredlogs==15.0.1
# logging==0.5.1.2

# %%
import pkg_resources
from IPython.display import display
import pandas as pd

root_packages = [
    'geoviews', 'geopandas', 'pandas', 'numpy', 'cloudpickle',
    'matplotlib', 'shapely', 'cartopy', 'holoviews',
    'mapclassify', 'fiona', 'bokeh', 'pyproj', 'ipython',
    'jupyterlab','logging','coloredlogs','delight','rail']
root_packages.sort(reverse=True)
root_packages_list = []

for m in pkg_resources.working_set:
    if m.project_name.lower() in root_packages:
        root_packages_list.append([m.project_name, m.version])

display(pd.DataFrame(
            root_packages_list,
            columns=["package", "version"]
        ).set_index("package").transpose())
# Out:
# package pandas   numpy matplotlib jupyterlab ipython holoviews coloredlogs  \
# version  1.2.4  1.21.2      3.3.4     3.0.14  7.22.0    1.14.6      15.0.1
#
# package cloudpickle  bokeh      rail delight
# version       1.6.0  2.3.2  0.1.dev0   1.0.1

# %%
from sinfo import sinfo
sinfo()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-9005812ffecd> in <module>
# ----> 1 from sinfo import sinfo
#       2 sinfo()
#
# ModuleNotFoundError: No module named 'sinfo'

# %%
# To list all installed packages just execfile THIS file
# execfile('list_all_pkgs.py')
for dist in __import__('pkg_resources').working_set:
   #print(dist.project_name.replace('Python', ''))
   print(dist.project_name)
# Out:
# zope.interface
# zope.event
# zipp
# zict
# yapf
# xmltodict
# xlwt
# xlwings
# XlsxWriter
# xlrd
# xgboost
# xarray
# wurlitzer
# wrapt
# widgetsnbextension
# wheel
# Werkzeug
# webencodings
# wcwidth
# watchdog
# ViTables
# urllib3
# unicodecsv
# ujson
# tzlocal
# typing-extensions
# typed-ast
# traitlets
# tqdm
# tornado
# toolz
# tomli
# toml
# timezonefinder
# tifffile
# three-merge
# threadpoolctl
# textdistance
# testpath
# terminado
# tenacity
# tblib
# tables
# tables-io
# sympy
# stdlib-list
# statsmodels
# stackyter
# SQLAlchemy
# spyder
# spyder-kernels
# sphinxcontrib-websupport
# sphinxcontrib-serializinghtml
# sphinxcontrib-qthelp
# sphinxcontrib-jsmath
# sphinxcontrib-htmlhelp
# sphinxcontrib-devhelp
# sphinxcontrib-applehelp
# Sphinx
# soupsieve
# sortedcontainers
# sortedcollections
# snowballstemmer
# sniffio
# skyfield
# sklearn
# six
# singledispatch
# sinfo
# simplegeneric
# sgp4
# setuptools
# setuptools-scm
# setuptools-scm-git-archive
# Send2Trash
# semantic-version
# seaborn
# scipy
# scikit-learn
# scikit-image
# schwimmbad
# ruamel-yaml-conda
# Rtree
# rope
# retrying
# requests
# regex
# QtPy
# qtconsole
# QtAwesome
# qp
# QDarkStyle
# pzflow
# pyzmq
# PyYAML
# PyWavelets
# pyvo
# pyviz-comms
# pytz
# python-mimeparse
# python-language-server
# python-jsonrpc-server
# python-dateutil
# pytest
# pytest-remotedata
# pytest-openfiles
# pytest-mock
# pytest-filter-subpackage
# pytest-doctestplus
# pytest-cov
# pytest-astropy
# pytest-astropy-header
# pytest-arraydiff
# pysynphot
# PySocks
# pyrsistent
# PyQtWebEngine
# PyQtChart
# PyQt5
# PyQt5-sip
# pyparsing
# pyOpenSSL
# pyodbc
# pyls-spyder
# pyls-black
# pylint
# Pygments
# pyflakes
# pyerfa
# pydocstyle
# pycurl
# pyct
# pycparser
# pycosat
# pycodestyle
# pyarrow
# py
# ptyprocess
# psutil
# prompt-toolkit
# prometheus-client
# ply
# pluggy
# plotly
# pkginfo
# pip
# Pillow
# pickleshare
# photutils
# pexpect
# pep8
# patsy
# pathtools
# pathspec
# pathlib2
# path
# partd
# parso
# param
# panel
# pandocfilters
# pandas
# packaging
# opt-einsum
# openpyxl
# olefile
# numpydoc
# numpy
# numexpr
# numba
# notebook
# nose
# nltk
# networkx
# nest-asyncio
# nbformat
# nbconvert
# nbclient
# nbclassic
# navigator-updater
# mypy-extensions
# multipledispatch
# msgpack
# mpmath
# mpi4py
# more-itertools
# mock
# mkl-service
# mkl-random
# mkl-fft
# mistune
# mccabe
# matplotlib
# matplotlib-label-lines
# MarkupSafe
# Markdown
# lxml
# llvmlite
# libarchive-c
# lazy-object-proxy
# kiwisolver
# keyring
# jupyterlab
# jupyterlab-widgets
# jupyterlab-server
# jupyterlab-pygments
# jupyter
# jupyter-server
# jupyter-packaging
# jupyter-nbextensions-configurator
# jupyter-latex-envs
# jupyter-highlight-selected-word
# jupyter-core
# jupyter-contrib-nbextensions
# jupyter-contrib-core
# jupyter-console
# jupyter-client
# jsonschema
# json5
# jplephem
# joblib
# jmespath
# Jinja2
# jedi
# jdcal
# jaxlib
# jax
# itsdangerous
# isort
# ipywidgets
# ipython
# ipython-genutils
# ipykernel
# intervaltree
# iniconfig
# importlib-resources
# importlib-metadata
# iminuit
# imagesize
# imageio
# idna
# hypothesis
# humanfriendly
# html5lib
# holoviews
# HeapDict
# h5py
# gwcs
# greenlet
# gmpy2
# glob2
# gevent
# future
# fsspec
# flexcode
# flatbuffers
# Flask
# flake8
# filelock
# fastcache
# et-xmlfile
# entrypoints
# emcee
# docutils
# docopt
# distributed
# dill
# diff-match-patch
# desc-bpz
# Deprecated
# defusedxml
# decorator
# datashape
# datashader
# dask
# cytoolz
# Cython
# cycler
# cryptography
# coveralls
# coverage
# contextlib2
# configparser
# conda
# conda-verify
# conda-token
# conda-repo-cli
# conda-package-handling
# conda-content-trust
# conda-build
# coloredlogs
# colorcet
# colorama
# clyent
# cloudpickle
# click
# chart-studio
# chardet
# cffi
# certifi
# brotlipy
# Bottleneck
# boto
# bokeh
# bleach
# black
# bkcharts
# bitarray
# betamax
# beautifulsoup4
# backports.zoneinfo
# backports.weakref
# backports.tempfile
# backports.shutil-get-terminal-size
# backports.functools-lru-cache
# backcall
# Babel
# autopep8
# attrs
# atomicwrites
# async-generator
# astroquery
# astropy
# astroplan
# astroML
# astroid
# asn1crypto
# asdf
# argon2-cffi
# argh
# appscript
# appnope
# applaunchservices
# appdirs
# anyio
# anaconda-project
# anaconda-navigator
# anaconda-client
# alabaster
# absl-py
# Spectractor
# mimeparse
# staralt
# rail
# delight
# locket
